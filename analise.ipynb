# %% [markdown]
# # Horários ônibus, linha 150, Terminal Fazenda/Cordeiros
#
# http://200.195.174.242:86/ITSReports/
#
# ITS Reports - Operação - Cumprimento de Serviço
#
# Data: 2018 / 2021
#
# legenda | descrição
# --------|------------------
# IP      | Inicio Previsto
# IR      | Inicio Realizado
# FP      | Fim Previsto
# FR      | Fim Realizado
# PP      | Prefixo Previsto
# PR      | Prefixo Realizado
# V       | Viagem

# %% [markdown]
# # Leitura dos dados

# %%
import numpy as np
import pandas as pd
import os
from datetime import date, timedelta, datetime

pd.set_option('display.max_columns', 45)

# %%
wpath = os.getcwd()
path = f'{wpath}/dados/linha_150'
pastas = os.listdir(path)
print(pastas)
# Out:
# ['2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03', '2021-04', '2021-05', '2021-06', '2021-07', '2021-08', '2021-09']

# %%
dadosXls = []

for p in pastas:
    arquivos = os.listdir(f'{path}/{p}')
    for x in arquivos:
        if '.xlsx' in x:
            data = pd.read_excel(f'{path}/{p}/{x}')
            dadosXls.append(data)

dadosXls = pd.concat(dadosXls)
dadosXls.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0         NaN                                                NaN         NaN
# 1         NaN                                                NaN         NaN
# 2         NaN  Data: 10/01/2018 - Linha: 150 - Todos os Servi...         NaN
# 3         NaN                                                NaN         NaN
# 4         NaN                                                NaN         NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN
#
#                Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0  Cumprimento de Serviço         NaN         NaN         NaN         NaN
# 1                     NaN         NaN         NaN         NaN         NaN
# 2                     NaN         NaN         NaN         NaN         NaN
# 3                     NaN         NaN         NaN         NaN         NaN
# 4                     NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 20  Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0         NaN          NaN         NaN         NaN         NaN
# 1         NaN          NaN         NaN         NaN         NaN
# 2         NaN          NaN         NaN         NaN         NaN
# 3         NaN          NaN         NaN         NaN         NaN
# 4         NaN          NaN         NaN         NaN         NaN

# %%
dadosXls['Unnamed: 3'] = dadosXls['Unnamed: 3'].fillna(method="ffill")

dadosXls['Unnamed: 1'].where(
    dadosXls['Unnamed: 1'].str.contains("Data: "), inplace=True)

dadosXls['Unnamed: 1'] = dadosXls['Unnamed: 1'].fillna(method="ffill")

# %%
dados = dadosXls.loc[dadosXls['Unnamed: 5'].isin(['IDA', 'VOLTA'])]

# %%
dados.head(3)
# Out:
#     Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 11         NaN  Data: 10/01/2018 - Linha: 150 - Todos os Servi...         NaN
# 12         NaN  Data: 10/01/2018 - Linha: 150 - Todos os Servi...         NaN
# 13         NaN  Data: 10/01/2018 - Linha: 150 - Todos os Servi...         NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5   Unnamed: 6   Unnamed: 7  Unnamed: 8  \
# 11  Serviço: 11          1        IDA  10/01 05:25  10/01 05:25         NaN
# 12  Serviço: 11          2      VOLTA  10/01 05:55  10/01 05:58         NaN
# 13  Serviço: 11          3        IDA  10/01 06:35  10/01 06:37         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 11        NaN  10/01 05:55  10/01 05:39           -           -
# 12        NaN  10/01 06:25  10/01 06:12           -           -
# 13        NaN  10/01 07:05  10/01 06:54           -           -
#
#            Unnamed: 14         Unnamed: 15 Unnamed: 16  \
# 11  Terminal Cordeiros    Terminal Fazenda          11
# 12    Terminal Fazenda  Terminal Cordeiros          11
# 13  Terminal Cordeiros    Terminal Fazenda          11
#
#                                       Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 11  150_A - Terminal Cordeiros > Terminal Fazenda          --          --
# 12  150_A - Terminal Cordeiros > Terminal Fazenda          --          --
# 13  150_A - Terminal Cordeiros > Terminal Fazenda          --          --
#
#    Unnamed: 20  Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 11      0,00 %          NaN      Manual     Paradas  HistÃ³rico
# 12      0,00 %          NaN      Manual     Paradas  HistÃ³rico
# 13      0,00 %          NaN      Manual     Paradas  HistÃ³rico

# %%
dados.loc[:,'date'] = pd.to_datetime(
    dados['Unnamed: 1'].str.slice(6, 16), format='%d/%m/%Y')

dados.loc[:,'linha'] = dados['Unnamed: 1'].str.slice(26, 29)

# %%
dados.loc[:, 'inicior'] = dados['Unnamed: 1'].str[12: 16]+'-' \
    + dados['Unnamed: 1'].str[9: 11]+'-' + \
    dados['Unnamed: 1'].str[6: 8]+' ' + \
    dados['Unnamed: 7'].str[6: 8] + dados['Unnamed: 7'].str[9: 11]

dados.loc[:, 'inicior'] = pd.to_datetime(dados.loc[:, 'inicior'])
# Out:
# /home/jaceguay/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92372 entries, 11 to 58
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   92372 non-null  object
#  2   Unnamed: 2   0 non-null      float64
#  3   Unnamed: 3   92372 non-null  object
#  4   Unnamed: 4   92372 non-null  object
#  5   Unnamed: 5   92372 non-null  object
#  6   Unnamed: 6   92372 non-null  object
#  7   Unnamed: 7   92372 non-null  object
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      object
#  10  Unnamed: 10  92372 non-null  object
#  11  Unnamed: 11  92372 non-null  object
#  12  Unnamed: 12  92372 non-null  object
#  13  Unnamed: 13  92372 non-null  object
#  14  Unnamed: 14  92372 non-null  object
#  15  Unnamed: 15  92372 non-null  object
#  16  Unnamed: 16  92372 non-null  object
#  17  Unnamed: 17  92372 non-null  object
#  18  Unnamed: 18  92372 non-null  object
#  19  Unnamed: 19  92372 non-null  object
#  20  Unnamed: 20  68020 non-null  object
#  21  Unnamed: 21  0 non-null      float64
#  22  Unnamed: 22  68020 non-null  object
#  23  Unnamed: 23  68020 non-null  object
#  24  Unnamed: 24  68020 non-null  object
#  25  date         92372 non-null  datetime64[ns]
#  26  linha        92372 non-null  object
#  27  iniciortemp  92372 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), object(22)
# memory usage: 22.5+ MB
