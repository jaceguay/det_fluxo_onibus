# %% [markdown]
# # Horários ônibus, linha 150, Terminal Fazenda/Cordeiros
#
# http://200.195.174.242:86/ITSReports/
#
# ITS Reports - Operação - Cumprimento de Serviço
#
# Data: 2018 / 2021
#
# legenda | descrição
# --------|------------------
# IP      | Inicio Previsto
# IR      | Inicio Realizado
# FP      | Fim Previsto
# FR      | Fim Realizado
# PP      | Prefixo Previsto
# PR      | Prefixo Realizado
# V       | Viagem

# %% [markdown]
# # Leitura dos dados

# %%
import numpy as np
import pandas as pd
import os
from datetime import date, timedelta, datetime

pd.set_option('display.max_columns', 45)

# %%
wpath = os.getcwd()
path = f'{wpath}/dados/linha_150'
pastas = os.listdir(path)
print(pastas)
# Out:
# ['2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03', '2021-04', '2021-05', '2021-06', '2021-07', '2021-08', '2021-09']

# %%
dadosXls = []

for p in pastas:
    arquivos = os.listdir(f'{path}/{p}')
    for x in arquivos:
        if '.xlsx' in x:
            data = pd.read_excel(f'{path}/{p}/{x}')
            dadosXls.append(data)

dadosXls = pd.concat(dadosXls)
dadosXls.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0         NaN                                                NaN         NaN
# 1         NaN                                                NaN         NaN
# 2         NaN  Data: 10/01/2018 - Linha: 150 - Todos os Servi...         NaN
# 3         NaN                                                NaN         NaN
# 4         NaN                                                NaN         NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN
#
#                Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0  Cumprimento de Serviço         NaN         NaN         NaN         NaN
# 1                     NaN         NaN         NaN         NaN         NaN
# 2                     NaN         NaN         NaN         NaN         NaN
# 3                     NaN         NaN         NaN         NaN         NaN
# 4                     NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 20  Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0         NaN          NaN         NaN         NaN         NaN
# 1         NaN          NaN         NaN         NaN         NaN
# 2         NaN          NaN         NaN         NaN         NaN
# 3         NaN          NaN         NaN         NaN         NaN
# 4         NaN          NaN         NaN         NaN         NaN

# %%
dadosXls['Unnamed: 3'] = dadosXls['Unnamed: 3'].fillna(method="ffill")

dadosXls['Unnamed: 1'].where(
    dadosXls['Unnamed: 1'].str.contains("Data: "), inplace=True)

dadosXls['Unnamed: 1'] = dadosXls['Unnamed: 1'].fillna(method="ffill")

# %%
dados = dadosXls.loc[dadosXls['Unnamed: 5'].isin(['IDA', 'VOLTA'])]

# %%
dados.head(3)
# Out:
#     Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 11         NaN  Data: 10/01/2018 - Linha: 150 - Todos os Servi...         NaN
# 12         NaN  Data: 10/01/2018 - Linha: 150 - Todos os Servi...         NaN
# 13         NaN  Data: 10/01/2018 - Linha: 150 - Todos os Servi...         NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5   Unnamed: 6   Unnamed: 7  Unnamed: 8  \
# 11  Serviço: 11          1        IDA  10/01 05:25  10/01 05:25         NaN
# 12  Serviço: 11          2      VOLTA  10/01 05:55  10/01 05:58         NaN
# 13  Serviço: 11          3        IDA  10/01 06:35  10/01 06:37         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 11        NaN  10/01 05:55  10/01 05:39           -           -
# 12        NaN  10/01 06:25  10/01 06:12           -           -
# 13        NaN  10/01 07:05  10/01 06:54           -           -
#
#            Unnamed: 14         Unnamed: 15 Unnamed: 16  \
# 11  Terminal Cordeiros    Terminal Fazenda          11
# 12    Terminal Fazenda  Terminal Cordeiros          11
# 13  Terminal Cordeiros    Terminal Fazenda          11
#
#                                       Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 11  150_A - Terminal Cordeiros > Terminal Fazenda          --          --
# 12  150_A - Terminal Cordeiros > Terminal Fazenda          --          --
# 13  150_A - Terminal Cordeiros > Terminal Fazenda          --          --
#
#    Unnamed: 20  Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 11      0,00 %          NaN      Manual     Paradas  HistÃ³rico
# 12      0,00 %          NaN      Manual     Paradas  HistÃ³rico
# 13      0,00 %          NaN      Manual     Paradas  HistÃ³rico

# %%
dados['date'] = pd.to_datetime(
    dados['Unnamed: 1'].str.slice(6, 16), format='%d/%m/%Y')

dados['linha'] = dados['Unnamed: 1'].str.slice(26, 29)
# Out:
# /tmp/ipykernel_221/351075479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['date'] = pd.to_datetime(
# /tmp/ipykernel_221/351075479.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['linha'] = dados['Unnamed: 1'].str.slice(26, 29)

# %%
dados['iniciortemp'] = dados['Unnamed: 1'].str[12: 16]+'-' + dados['Unnamed: 1'].str[9: 11]+'-' + \
    dados['Unnamed: 1'].str[6: 8]+' ' + dados['Unnamed: 7'].str[6: 8] + \
    ':' + dados['Unnamed: 7'].str[9: 11]

dados['inicioregistr'] = dados['iniciortemp'].astype('datetime64[ns]')
# Out:
# /tmp/ipykernel_221/2820154187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['iniciortemp'] = dados['Unnamed: 1'].str[12: 16]+'-' + dados['Unnamed: 1'].str[9: 11]+'-' + \
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2186         try:
# -> 2187             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2188             # If tzaware, these values represent unix timestamps, so we
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_221/2820154187.py in <module>
#       3     ':' + dados['Unnamed: 7'].str[9: 11]
#       4
# ----> 5 dados['inicioregistr'] = dados['iniciortemp'].astype('datetime64[ns]')
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     590         values = self.values
#     591
# --> 592         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     593
#     594         new_values = maybe_coerce_values(new_values)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/.local/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~/.local/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1181
#    1182             return astype_nansafe(
# -> 1183                 to_datetime(arr).values,
#    1184                 dtype,
#    1185                 copy=copy,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     910             result = _convert_and_box_cache(arg, cache_array)
#     911         else:
# --> 912             result = convert_listlike(arg, format)
#     913     else:
#     914         result = convert_listlike(np.array([arg]), format)[0]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     399     assert format is None or infer_datetime_format
#     400     utc = tz == "utc"
# --> 401     result, tz_parsed = objects_to_datetime64ns(
#     402         arg,
#     403         dayfirst=dayfirst,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2191             return values.view("i8"), tz_parsed
#    2192         except (ValueError, TypeError):
# -> 2193             raise err
#    2194
#    2195     if tz_parsed is not None:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2173     order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2174     try:
# -> 2175         result, tz_parsed = tslib.array_to_datetime(
#    2176             data.ravel("K"),
#    2177             errors=errors,
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/.local/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1366         return parser(parserinfo).parse(timestr, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#    1370
#
# ~/.local/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     641
#     642         if res is None:
# --> 643             raise ParserError("Unknown string format: %s", timestr)
#     644
#     645         if len(res) == 0:
#
# ParserError: Unknown string format: 2018-01-10 :
